# %%
import numpy as np
import pandas as pd
import os
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from keras_vggface.vggface import VGGFace
from keras_vggface import utils
# Out:
# 2022-11-25 12:52:44.755489: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# create a vggface model
model = VGGFace(model='senet50')
model.summary()
# model = VGGFace(model='ressenet50net50', include_top=False, input_shape=(224, 224, 3))
# Out:
# 2022-11-25 12:53:01.060944: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-25 12:53:01.061710: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-25 12:53:01.061759: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# summarize input and output shape
layer_name = 'flatten'
out = model.get_layer(layer_name).output
model = Model(model.input, out)
print('Inputs: %s' % model.inputs)
print('Outputs: %s' % model.outputs)
target_shape = (224, 224)
# Out:
# Inputs: [<KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'input_1')>]
# Outputs: [<KerasTensor: shape=(None, 2048) dtype=float32 (created by layer 'flatten')>]

# %%
db_path = '/Users/santhoshnarayanan/Documents/Turing/GPU/VGGData/testset'
celebs  = []
 
for r, d, f in os.walk(db_path): # r=root, d=directories, f = files
    for file in f:
        if ('.jpg' in file):
            exact_path = r + "/" + file
            celebs.append(exact_path)

# %%
imgs = [image.load_img(img, target_size=target_shape) for img in celebs]
X = np.float32([utils.preprocess_input(np.float32(img), version=1) for img in imgs])
display(X.shape)
# Out:
# (8000, 224, 224, 3)

# %%
repA = model.predict(X[0:4000], batch_size=64)
display(repA.shape)
repB = model.predict(X[4000:8000], batch_size=64)
display(repB.shape)
rep = np.concatenate((repA, repB), axis=0)
display(rep.shape)
# Out:
# 2022-11-25 12:53:58.009903: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 63/63 [==============================] - 34s 452ms/step
# (4000, 2048)
# 63/63 [==============================] - 26s 380ms/step
# (4000, 2048)
# (8000, 2048)

# %%
df = pd.DataFrame(rep)  
df.insert(loc = 0,
          column = 'celeb',
          value = celebs)
display(df)
# Out:
#                                                   celeb         0         1  \
# 0     /Users/santhoshnarayanan/Documents/Turing/GPU/...  0.054439  0.094443
# 1     /Users/santhoshnarayanan/Documents/Turing/GPU/...  0.000093  0.802021
# 2     /Users/santhoshnarayanan/Documents/Turing/GPU/...  0.135477  1.477068
# 3     /Users/santhoshnarayanan/Documents/Turing/GPU/...  0.651370  0.003956
# 4     /Users/santhoshnarayanan/Documents/Turing/GPU/...  0.591312  3.848584
# ...                                                 ...       ...       ...
# 7995  /Users/santhoshnarayanan/Documents/Turing/GPU/...  0.032277  0.171074
# 7996  /Users/santhoshnarayanan/Documents/Turing/GPU/...  0.019115  0.024145
# 7997  /Users/santhoshnarayanan/Documents/Turing/GPU/...  0.536209  0.023760
# 7998  /Users/santhoshnarayanan/Documents/Turing/GPU/...  0.026188  2.405983
# 7999  /Users/santhoshnarayanan/Documents/Turing/GPU/...  0.053714  1.254792
#
# ...

# %%
df.to_csv('rep_SENET.csv')
